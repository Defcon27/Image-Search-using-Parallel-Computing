# %%
import os
import cv2
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ImageSearch_Serial import ImageSearch

# %% [markdown]
# #

# %% [markdown]
# ##

# %%
res = ImageSearch("101400.jpg")

# %%
print(res)
# Out:
# [('101400.jpg', 0.0), ('101402.jpg', 148278.79723), ('101403.jpg', 213945.42471), ('101401.jpg', 253762.31026), ('113000.jpg', 350950.7387), ('120600.jpg', 376451.93847), ('100201.jpg', 377820.64578), ('road.jpg', 378139.9841), ('101404.jpg', 382665.77571), ('100901.jpg', 385629.84359), ('100601.jpg', 386595.64419), ('101702.jpg', 387653.74376), ('101600.jpg', 389888.42893), ('101601.jpg', 392705.12217), ('121601.jpg', 392846.99228), ('102900.jpg', 393791.38670000003), ('100800.jpg', 396106.92786), ('100600.jpg', 398546.595), ('noisy.jpg', 403086.65986), ('100301.jpg', 407618.22908), ('101201.jpg', 409392.48945), ('100801.jpg', 409579.67611), ('101901.jpg', 411340.53181), ('100902.jpg', 412274.19947), ('101200.jpg', 413629.08144), ('100302.jpg', 414245.49256), ('100200.jpg', 421873.40699), ('101300.jpg', 422476.97526), ('101100.jpg', 423209.36935), ('100300.jpg', 430734.50245), ('101301.jpg', 433485.39074), ('100503.jpg', 433798.97859), ('100400.jpg', 434005.90241), ('101900.jpg', 434566.02633), ('100501.jpg', 441198.24878), ('100502.jpg', 441511.58795), ('100401.jpg', 442114.20515), ('101504.jpg', 443550.73727), ('100001.jpg', 443647.19993999996), ('100000.jpg', 446391.61612), ('101101.jpg', 450599.85636), ('101501.jpg', 450696.16701), ('100101.jpg', 450939.56438), ('100701.jpg', 452291.39601), ('101000.jpg', 452782.9449), ('100100.jpg', 454529.68454), ('101001.jpg', 455622.16592), ('100700.jpg', 461310.55195), ('100500.jpg', 461643.86322), ('100002.jpg', 464969.07763), ('101502.jpg', 472652.45957), ('100900.jpg', 474230.00318), ('101701.jpg', 480823.52696), ('101500.jpg', 485023.03138), ('101700.jpg', 486267.02963999996), ('101503.jpg', 487289.89086), ('102001.jpg', 495049.3453), ('102000.jpg', 495588.45139), ('101800.jpg', 500263.94085), ('101801.jpg', 500325.89506999997)]

# %%
def getImg(img):
    image_db_path = "Image_Database/"
    image = cv2.imread(image_db_path+img)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# f,ax = plt.subplots(10, 3, figsize=(50,50))
# for i in range(10):
#     ax[i,0].imshow(getImg(res[i][0]))
#     ax[i,1].imshow(getImg(res[i][0]))

# %%
plt.figure(figsize=(20,20)) 

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(getImg(res[i][0]))

plt.show()
