# %%
import os
import cv2
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ImageSearch_Serial import ImageSearch

# %% [markdown]
# #

# %% [markdown]
# ##

# %%
res = ImageSearch("101400.jpg")

# %%
print(res)
# Out:
# [('101800.jpg', 1e-05), ('101801.jpg', 1e-05), ('102000.jpg', 0.00159), ('102001.jpg', 0.00185), ('101700.jpg', 0.02208), ('101500.jpg', 0.02631), ('101503.jpg', 0.03021), ('101701.jpg', 0.03589), ('100000.jpg', 0.04842), ('101101.jpg', 0.05603), ('101502.jpg', 0.05919), ('100500.jpg', 0.06071), ('101001.jpg', 0.08344), ('100001.jpg', 0.08461), ('100900.jpg', 0.08544), ('101501.jpg', 0.08962), ('100002.jpg', 0.0915), ('100700.jpg', 0.09456), ('100701.jpg', 0.09929), ('101000.jpg', 0.1015), ('100100.jpg', 0.10314), ('100501.jpg', 0.1078), ('101504.jpg', 0.10942), ('100101.jpg', 0.11633), ('100401.jpg', 0.1237), ('100503.jpg', 0.12727), ('100502.jpg', 0.13032), ('101100.jpg', 0.13225), ('101200.jpg', 0.15676), ('100902.jpg', 0.1591), ('100600.jpg', 0.16477), ('101301.jpg', 0.16714), ('100400.jpg', 0.1716), ('101201.jpg', 0.17301), ('101300.jpg', 0.18087), ('102900.jpg', 0.19383), ('101404.jpg', 0.19859), ('100300.jpg', 0.20126), ('100200.jpg', 0.20412), ('100601.jpg', 0.21124), ('101900.jpg', 0.21419), ('100901.jpg', 0.21831), ('100801.jpg', 0.23256), ('noisy.jpg', 0.23529), ('121601.jpg', 0.23569), ('100800.jpg', 0.24671), ('113000.jpg', 0.25072), ('120600.jpg', 0.27001), ('100302.jpg', 0.27691), ('101901.jpg', 0.28517), ('100301.jpg', 0.3135), ('road.jpg', 0.32375), ('101702.jpg', 0.32968), ('100201.jpg', 0.34916), ('101601.jpg', 0.37163), ('101600.jpg', 0.39419), ('101401.jpg', 0.51724), ('101403.jpg', 0.74274), ('101402.jpg', 0.8171), ('101400.jpg', 1.0)]

# %%
def getImg(img):
    image_db_path = "Image_Database/"
    image = cv2.imread(image_db_path+img)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# f,ax = plt.subplots(10, 3, figsize=(50,50))
# for i in range(10):
#     ax[i,0].imshow(getImg(res[i][0]))
#     ax[i,1].imshow(getImg(res[i][0]))

# %%
plt.figure(figsize=(20,20)) 

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(getImg(res[i][0]))

plt.show()
