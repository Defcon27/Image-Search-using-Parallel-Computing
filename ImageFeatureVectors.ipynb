# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
image = cv2.imread("Image_Database/120600.jpg")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image = cv2.resize(image,(500,500))

plt.imshow(image)

# %%
np.average(image[:,:,1])
# Out:
# 114.529276

# %%
for channel in range(3):
    print(np.std(image[:,:,channel]))
# Out:
# 67.68464793754886
# 65.73264971774547
# 68.47955372686361

# %%
from FeatureVectors import FeatureVectors

featureVectors = FeatureVectors(image)
vectors = featureVectors.getFeatureVector()

vectors
# Out:
# [113.83251, 114.52928, 106.43264, 67.68465, 65.73265, 68.47955]

# %%
image = "Image_Database/120600.jpg"

image.split("/")[-1]
# Out:
# '120600.jpg'

# %%
def hi():
    
    return ("a","b")

# %%
a,b=hi()

# %%
a
# Out:
# 'a'

# %%
a=hi()

# %%
a[0]
# Out:
# 'a'

# %%
a[1]
# Out:
# 'b'
